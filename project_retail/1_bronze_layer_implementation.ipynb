# %%
catalog_name = "retail_cat"
df = spark.read.parquet("/Volumes/retail_cat/raw/raw_data/customers.parquet")
df.write.format("delta") \
  .mode("overwrite") \
  .option("mergeSchema", "true") \
  .saveAsTable(f"{catalog_name}.bronze.brz_customers")

# %%
df = spark.read.parquet("/Volumes/retail_cat/raw/raw_data/dbo.products.parquet")
df.write.format("delta") \
  .mode("overwrite") \
  .option("mergeSchema", "true") \
  .saveAsTable(f"{catalog_name}.bronze.brz_products")

# %%
df = spark.read.parquet("/Volumes/retail_cat/raw/raw_data/dbo.stores.parquet")
df.write.format("delta") \
  .mode("overwrite") \
  .option("mergeSchema", "true") \
  .saveAsTable(f"{catalog_name}.bronze.brz_stores")

# %%
df = spark.read.parquet("/Volumes/retail_cat/raw/raw_data/dbo.transactions.parquet")
df.write.format("delta") \
  .mode("overwrite") \
  .option("mergeSchema", "true") \
  .saveAsTable(f"{catalog_name}.bronze.brz_transactions")

# %%
# %sql

select count(1) from retail_cat.bronze.brz_products;
