# %%
# %sql

create catalog if not exists atlikon;

# %%
# %sql

create schema if not exists atlikon.bronze;
create schema if not exists atlikon.silver;
create schema if not exists atlikon.gold;

# %%
# %sql

select count(1) from atlikon.gold.fact_orders;
